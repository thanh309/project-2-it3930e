# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil import parser

df = pd.read_csv('resources/data_v3.csv')

def parse_mixed_date(date_str):
    try:
        return parser.parse(date_str, dayfirst=True)
    except Exception:
        return pd.NaT

# df = df.iloc[:-8]
df['Scan date'] = df['Scan date'].astype(str).apply(parse_mixed_date)
df['Commit frequency'] = df['Commit frequency'].str.capitalize()
# df['Scan date'] = pd.to_datetime(df['Scan date'], errors='coerce', dayfirst=False)
label_map = {
    'Very low': 0,
    'Low': 1,
    'Medium': 2,
    'High': 3,
    'Very high': 4
}
df['Evaluate'] = df["Evaluate"].map(label_map)


df_copy = df.loc[:, (df != 0).any(axis=0)]
df_copy = df_copy.drop(labels=['Sprint'], axis=1)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 13 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Change code line number                                783 non-null    int64
#  1   Number of vulnerable modules                           783 non-null    int64
#  2   Number of people involved in development               783 non-null    int64
#  3   Time to complete each version                          783 non-null    object
#  4   Commit frequency                                       783 non-null    object
#  5   Type of environment                                    783 non-null    object
#  6   Number of libraries detected errors                    783 non-null    int64
#  7   Scan date                                              783 non-null    datetime64[ns]
#  8   Number of potential weaknesses                         783 non-null    int64
#  9   Severity of the threat                                 783 non-null    int64
#  10  Number of environmental configuration vulnerabilities  783 non-null    int64
#  11  Evaluate                                               783 non-null    int64
#  12  Repo                                                   783 non-null    object
# dtypes: datetime64[ns](1), int64(8), object(4)
# memory usage: 79.7+ KB

# %%
df_copy
# Out:
#      Change code line number  Number of vulnerable modules  \
# 0                        527                             1
# 1                       1505                             1
# 2                         66                             1
# 3                       1055                             1
# 4                        769                             1
# ..                       ...                           ...
# 778                      131                             1
# 779                      126                             1
# 780                      129                             1
# 781                      135                             1
# 782                      134                             1
#
#      Number of people involved in development Time to complete each version  \
# 0                                           3                        7 days
# 1                                           2                        7 days
# 2                                           1                        5 days
# 3                                           8                       10 days
# 4                                           3                       10 days
# ..                                        ...                           ...
# 778                                         3                        7 days
# 779                                         3                        7 days
# 780                                         3                        7 days
# 781                                         3                        7 days
# 782                                         3                        7 days
#
#     Commit frequency Type of environment  Number of libraries detected errors  \
# 0              Daily               Cloud                                   15
# 1            Monthly               Cloud                                   45
# 2            Monthly               Cloud                                   22
# 3             Weekly               Cloud                                   43
# 4              Daily               Cloud                                   32
# ..               ...                 ...                                  ...
# 778           Weekly                 VPS                                    9
# 779           Weekly                 VPS                                    9
# 780           Weekly                 VPS                                    9
# 781           Weekly                 VPS                                    9
# 782           Weekly                 VPS                                    9
#
#      Scan date  Number of potential weaknesses  Severity of the threat  \
# 0   2025-01-01                              19                       3
# 1   2025-01-01                              49                       3
# 2   2025-01-01                              26                       4
# 3   2025-01-01                              46                       4
# 4   2025-01-01                              36                       4
# ..         ...                             ...                     ...
# 778 2023-02-17                              14                       2
# 779 2024-05-19                              14                       2
# 780 2023-02-24                              14                       2
# 781 2023-06-10                              14                       2
# 782 2024-08-25                              14                       2
#
#      Number of environmental configuration vulnerabilities  Evaluate  \
# 0                                                    4             3
# 1                                                    4             3
# 2                                                    4             2
# 3                                                    3             2
# 4                                                    4             2
# ..                                                 ...           ...
# 778                                                  5             1
# 779                                                  5             1
# 780                                                  5             1
# 781                                                  5             1
# 782                                                  5             1
#
#                 Repo
# 0    user-management
# 1    user-management
# 2         admin-jlpt
# 3     payment-system
# 4         admin-jlpt
# ..               ...
# 778       Vue-trello
# 779       Vue-trello
# 780       Vue-trello
# 781       Vue-trello
# 782       Vue-trello
#
# [783 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

def preprocess_timeseries_dataframe(df: pd.DataFrame):
    df = df.copy()
    df = df.loc[:, (df != 0).any(axis=0)]
    df = df.drop(labels=['Sprint'], axis=1)
    df['Scan date'] = pd.to_datetime(df['Scan date'])

    categorical_columns = ['Time to complete each version', 'Commit frequency', 'Type of environment', 'Repo']
    group_sum_col = 'Change code line number'
    target_col = 'Evaluate'
    date_col = 'Scan date'

    all_dfs = []
    for repo, group in df.groupby('Repo'):
        # group by date to avoid duplicates before reindexing
        group = group.groupby(date_col).agg({
            group_sum_col: 'sum',
            'Number of vulnerable modules': 'mean',
            'Number of people involved in development': 'mean',
            'Number of libraries detected errors': 'mean',
            'Number of potential weaknesses': 'mean',
            'Severity of the threat': 'mean',
            'Number of environmental configuration vulnerabilities': 'mean',
            target_col: 'first',
            **{col: 'first' for col in categorical_columns}
        }).sort_index()

        # create full date index and reindex
        all_dates = pd.date_range(start=group.index.min(), end=group.index.max(), freq='D')
        group = group.reindex(all_dates, method='ffill')
        group[date_col] = group.index
        group['Repo'] = repo

        # identify filled-in rows and set code line to 0
        original_dates = df[df['Repo'] == repo]['Scan date'].unique()
        group[group_sum_col] = group[group_sum_col].where(group.index.isin(original_dates), 0)

        all_dfs.append(group)

    df_filled = pd.concat(all_dfs).reset_index(drop=True)

    # encode categoricals
    label_encoders = {}
    for col in categorical_columns:
        le = LabelEncoder()
        df_filled[col] = le.fit_transform(df_filled[col])
        label_encoders[col] = le

    # normalize features (excluding Scan date, Repo, Evaluate)
    feature_cols = df_filled.columns.difference([date_col, 'Repo', target_col])
    scaler = StandardScaler()
    df_filled[feature_cols] = scaler.fit_transform(df_filled[feature_cols])

    # final outputs
    X = df_filled.drop(columns=[date_col, 'Repo', target_col])
    y = df_filled[target_col]
    meta = df_filled[[date_col, 'Repo']]

    return X, y, meta, label_encoders, scaler

# %%
X, y, meta, encoders, scaler = preprocess_timeseries_dataframe(df)
X
# Out:
#       Change code line number  Number of vulnerable modules  \
# 0                    0.324700                     -0.298289
# 1                    1.077030                     -0.298289
# 2                   -0.171837                     -0.298289
# 3                   -0.200050                     -0.298289
# 4                   -0.200050                     -0.298289
# ...                       ...                           ...
# 5117                -0.200050                     -0.298289
# 5118                -0.200050                     -0.298289
# 5119                -0.200050                     -0.298289
# 5120                -0.200050                     -0.298289
# 5121                 0.478928                     -0.298289
#
#       Number of people involved in development  \
# 0                                     0.296948
# 1                                     0.296948
# 2                                     0.296948
# 3                                     0.296948
# 4                                     0.296948
# ...                                        ...
# 5117                                  0.872569
# 5118                                  0.872569
# 5119                                  0.872569
# 5120                                  0.872569
# 5121                                  0.872569
#
#       Number of libraries detected errors  Number of potential weaknesses  \
# 0                                0.266051                        0.191212
# 1                                0.266051                        0.191212
# 2                                0.266051                        0.191212
# 3                                0.266051                        0.191212
# 4                                0.266051                        0.191212
# ...                                   ...                             ...
# 5117                            -0.949415                       -1.088630
# 5118                            -0.949415                       -1.088630
# 5119                            -0.949415                       -1.088630
# 5120                            -0.949415                       -1.088630
# 5121                            -0.949415                       -1.088630
#
#       Severity of the threat  \
# 0                   1.373858
# 1                   1.373858
# 2                   1.373858
# 3                   1.373858
# 4                   1.373858
# ...                      ...
# 5117               -1.197873
# 5118               -1.197873
# 5119               -1.197873
# 5120               -1.197873
# 5121               -1.197873
#
#       Number of environmental configuration vulnerabilities  \
# 0                                             -0.408835
# 1                                             -0.408835
# 2                                             -0.408835
# 3                                             -0.408835
# 4                                             -0.408835
# ...                                                 ...
# 5117                                          -1.414624
# 5118                                          -1.414624
# 5119                                          -1.414624
# 5120                                          -1.414624
# 5121                                          -1.414624
#
#       Time to complete each version  Commit frequency  Type of environment
# 0                          0.378975          0.402613             0.648087
# 1                          0.378975          0.402613             0.648087
# 2                          0.378975          0.402613             0.648087
# 3                          0.378975          0.402613             0.648087
# 4                          0.378975          0.402613             0.648087
# ...                             ...               ...                  ...
# 5117                       0.378975          0.402613             0.648087
# 5118                       0.378975          0.402613             0.648087
# 5119                       0.378975          0.402613             0.648087
# 5120                       0.378975          0.402613             0.648087
# 5121                       0.378975          0.402613             0.648087
#
# [5122 rows x 10 columns]

# %%
y
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 5117    0
# 5118    0
# 5119    0
# 5120    0
# 5121    0
# Name: Evaluate, Length: 5122, dtype: int64

# %%
meta
# Out:
#       Scan date  Repo
# 0    2024-05-16     0
# 1    2024-05-17     0
# 2    2024-05-18     0
# 3    2024-05-19     0
# 4    2024-05-20     0
# ...         ...   ...
# 5117 2024-10-02    19
# 5118 2024-10-03    19
# 5119 2024-10-04    19
# 5120 2024-10-05    19
# 5121 2024-10-06    19
#
# [5122 rows x 2 columns]

# %%
ori_X = scaler.inverse_transform(X[list(scaler.feature_names_in_)]).astype(int)
ori_X = pd.DataFrame(data=ori_X, columns=list(scaler.feature_names_in_))

# %%
for col in ('Time to complete each version', 'Commit frequency', 'Type of environment'):
    ori_X[col] = encoders[col].inverse_transform(ori_X[col])

# %%
ori_X
# Out:
#       Change code line number Commit frequency  \
# 0                         279           Weekly
# 1                         679           Weekly
# 2                          15           Weekly
# 3                           0           Weekly
# 4                           0           Weekly
# ...                       ...              ...
# 5117                        0           Weekly
# 5118                        0           Weekly
# 5119                        0           Weekly
# 5120                        0           Weekly
# 5121                      361           Weekly
#
#       Number of environmental configuration vulnerabilities  \
# 0                                                     2
# 1                                                     2
# 2                                                     2
# 3                                                     2
# 4                                                     2
# ...                                                 ...
# 5117                                                  0
# 5118                                                  0
# 5119                                                  0
# 5120                                                  0
# 5121                                                  0
#
#       Number of libraries detected errors  \
# 0                                      21
# 1                                      21
# 2                                      21
# 3                                      21
# 4                                      21
# ...                                   ...
# 5117                                    5
# 5118                                    5
# 5119                                    5
# 5120                                    5
# 5121                                    5
#
#       Number of people involved in development  \
# 0                                            3
# 1                                            3
# 2                                            3
# 3                                            3
# 4                                            3
# ...                                        ...
# 5117                                         4
# 5118                                         4
# 5119                                         4
# 5120                                         4
# 5121                                         4
#
#       Number of potential weaknesses  Number of vulnerable modules  \
# 0                                 23                             1
# 1                                 23                             1
# 2                                 23                             1
# 3                                 23                             1
# 4                                 23                             1
# ...                              ...                           ...
# 5117                               5                             1
# 5118                               5                             1
# 5119                               5                             1
# 5120                               5                             1
# 5121                               5                             1
#
#       Severity of the threat Time to complete each version Type of environment
# 0                          5                        7 days                 VPS
# 1                          5                        7 days                 VPS
# 2                          5                        7 days                 VPS
# 3                          5                        7 days                 VPS
# 4                          5                        7 days                 VPS
# ...                      ...                           ...                 ...
# 5117                       0                        7 days                 VPS
# 5118                       0                        7 days                 VPS
# 5119                       0                        7 days                 VPS
# 5120                       0                        7 days                 VPS
# 5121                       0                        7 days                 VPS
#
# [5122 rows x 10 columns]

# %%
ori_meta  = meta.copy()
ori_meta['Repo'] = encoders['Repo'].inverse_transform(ori_meta['Repo'])
ori_meta
# Out:
#       Scan date     Repo
# 0    2024-05-16   6am_BE
# 1    2024-05-17   6am_BE
# 2    2024-05-18   6am_BE
# 3    2024-05-19   6am_BE
# 4    2024-05-20   6am_BE
# ...         ...      ...
# 5117 2024-10-02  web-hly
# 5118 2024-10-03  web-hly
# 5119 2024-10-04  web-hly
# 5120 2024-10-05  web-hly
# 5121 2024-10-06  web-hly
#
# [5122 rows x 2 columns]

# %%
ori_y = pd.DataFrame(data=y, columns=['Evaluate'])
ori_y
# Out:
#       Evaluate
# 0            4
# 1            4
# 2            4
# 3            4
# 4            4
# ...        ...
# 5117         0
# 5118         0
# 5119         0
# 5120         0
# 5121         0
#
# [5122 rows x 1 columns]

# %%
col_names = list(ori_X.columns) + list(ori_meta.columns) + list(ori_y.columns)
ori_data = pd.concat([ori_X, ori_meta, ori_y], ignore_index=True, axis=1)
ori_data.columns = col_names
ori_data = ori_data[df_copy.columns.tolist()]
ori_data.to_csv('resources/data_cleaned_v3.csv', index=False)

# %% [markdown]
# ### Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Normal

class BayesianDense(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.w_mu = nn.Parameter(torch.Tensor(out_features, in_features))
        self.w_sigma = nn.Parameter(torch.Tensor(out_features, in_features))
        self.b_mu = nn.Parameter(torch.Tensor(out_features))
        self.b_sigma = nn.Parameter(torch.Tensor(out_features))
        self.reset_parameters()

    def reset_parameters(self):
        nn.init.kaiming_normal_(self.w_mu, mode='fan_in')
        nn.init.constant_(self.w_sigma, -3)
        nn.init.constant_(self.b_mu, 0.1)
        nn.init.constant_(self.b_sigma, -3)

    def forward(self, x):
        w = Normal(self.w_mu, torch.exp(self.w_sigma)).rsample()
        b = Normal(self.b_mu, torch.exp(self.b_sigma)).rsample()
        return F.linear(x, w, b)

class MyModel(nn.Module):
    def __init__(self, input_features=10, timesteps=5, num_classes=5):
        super().__init__()
        assert input_features == 10, 'only 10 features supported right now'

        self.input_dense = BayesianDense(input_features, 32)
        self.lstm = nn.LSTM(32, 64, num_layers=2, batch_first=True)

        self.bayesian_layers = nn.ModuleList([
            BayesianDense(64, 64),
            BayesianDense(64, 48),
            BayesianDense(48, 48),
            BayesianDense(48, 32)
        ])

        self.dropout = nn.Dropout(0.1)
        self.final_dense = BayesianDense(32, num_classes)

        self.swish = lambda x: x * torch.sigmoid(x)

    def forward(self, x):
        batch_size, T, _ = x.shape

        x = self.swish(self.input_dense(x))  # (batch, T, 32)
        lstm_out, _ = self.lstm(x)  # (batch, T, 64)

        x = lstm_out
        for layer in self.bayesian_layers:
            x = self.swish(layer(x))

        x = self.dropout(x)
        logits = self.final_dense(x)  # (batch, T, num_classes)
        return logits
    
def evaluate(model, loader, verbose=True):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for x_batch, y_batch in loader:
            output = model(x_batch)  # (batch, T, num_classes)
            preds = output.argmax(dim=-1)
            all_preds.append(preds.flatten())
            all_labels.append(y_batch.flatten())
    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)
    acc = (all_preds == all_labels).float().mean().item()
    if verbose:
        print(f"accuracy: {acc:.4f}")
    return acc

def train(model, loader, optimizer, criterion, val_loader=None, epochs=100):
    model.train()
    train_losses = []
    val_accuracies = []

    for epoch in range(epochs):
        total_loss = 0
        for x_batch, y_batch in loader:
            optimizer.zero_grad()
            output = model(x_batch)  # shape: (batch, T, num_classes)
            loss = criterion(output.view(-1, output.shape[-1]), y_batch.view(-1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(loader)
        train_losses.append(avg_loss)

        # Validation accuracy
        if val_loader:
            acc = evaluate(model, val_loader, verbose=False)
            val_accuracies.append(acc)

        print(f"epoch {epoch+1}: loss = {avg_loss:.4f}" + (f", val. acc. = {acc:.4f}" if val_loader else ""))

    return train_losses, val_accuracies

# %%
from torch.utils.data import Dataset, DataLoader, random_split

# class RepoDataset(Dataset):
#     def __init__(self, X_df, y_series, meta_df, timesteps=5):
#         self.samples = []
#         self.meta = []

#         grouped = meta_df.groupby("Repo")
#         for repo_id, group_indices in grouped.groups.items():
#             group = meta_df.loc[group_indices].sort_values("Scan date")
#             sorted_idx = group.index.tolist()
#             if len(sorted_idx) < timesteps:
#                 continue
#             for i in range(len(sorted_idx) - timesteps + 1):
#                 window_idx = sorted_idx[i:i + timesteps]
#                 x_seq = torch.tensor(X_df.loc[window_idx].values, dtype=torch.float32)
#                 y_seq = torch.tensor(y_series.loc[window_idx].values, dtype=torch.long)
#                 # meta_seq = meta_df.loc[window_idx].iloc[-1]
#                 self.samples.append((x_seq, y_seq))

#     def __len__(self):
#         return len(self.samples)

#     def __getitem__(self, idx):
#         return self.samples[idx]
    
# train_repos = [0, 1, 2]
# test_repos = [3]

# train_mask = meta['Repo'].isin(train_repos)
# test_mask = meta['Repo'].isin(test_repos)

# X_train = X[train_mask]
# y_train = y[train_mask]
# meta_train = meta[train_mask]

# X_test = X[test_mask]
# y_test = y[test_mask]
# meta_test = meta[test_mask]

# timesteps = 5
# train_dataset = RepoDataset(X_train, y_train, meta_train, timesteps=timesteps)
# test_dataset = RepoDataset(X_test, y_test, meta_test, timesteps=timesteps)

# batch_size = 32
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# model = MyModel(input_features=10, timesteps=timesteps, num_classes=5)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# criterion = nn.CrossEntropyLoss()

# train_losses, val_accuracies = train(
#     model, train_loader, optimizer, criterion,
#     val_loader=test_loader, epochs=200
# )

# plt.figure(figsize=(12, 5))

# plt.subplot(1, 2, 1)
# plt.plot(train_losses)
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Loss')
# plt.grid(True)

# plt.subplot(1, 2, 2)
# plt.plot(val_accuracies, color='green')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.title('Accuracy')
# plt.grid(True)

# plt.tight_layout()
# plt.show()

# %%
class RepoSplitTimeSeriesDataset(Dataset):
    def __init__(self, X_df, y_series, meta_df, timesteps=5, mode="train", split_ratio=0.8):
        self.samples = []
        assert mode in ["train", "val"], "mode must be 'train' or 'val'"

        grouped = meta_df.groupby("Repo")

        for repo_id, group_indices in grouped.groups.items():
            # sort by time within each repo
            group = meta_df.loc[group_indices].sort_values("Scan date")
            sorted_idx = group.index.tolist()

            total = len(sorted_idx)
            split_point = int(total * split_ratio)

            if total < timesteps:
                continue  # skip short repos

            if mode == "train":
                use_idx = sorted_idx[:split_point]
            else:  # val
                use_idx = sorted_idx[split_point:]

            # re-slide within the selected portion
            for i in range(len(use_idx) - timesteps + 1):
                window_idx = use_idx[i:i + timesteps]
                x_seq = torch.tensor(X_df.loc[window_idx].values, dtype=torch.float32)
                y_seq = torch.tensor(y_series.loc[window_idx].values, dtype=torch.long)
                meta_seq = meta_df.loc[window_idx].iloc[-1].to_dict()
                self.samples.append((x_seq, y_seq))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]
    

timesteps = 5
train_dataset = RepoSplitTimeSeriesDataset(X, y, meta, timesteps=timesteps, mode="train", split_ratio=0.1)
val_dataset = RepoSplitTimeSeriesDataset(X, y, meta, timesteps=timesteps, mode="val", split_ratio=0.1)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
len(train_dataset)
# Out:
# 440

# %%
model = MyModel(input_features=10, timesteps=timesteps, num_classes=5)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

train_losses, val_accuracies = train(
    model, train_loader, optimizer, criterion,
    val_loader=val_loader, epochs=200
)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# epoch 1: loss = 1.6318, val. acc. = 0.1761
# epoch 2: loss = 1.6068, val. acc. = 0.2322
# epoch 3: loss = 1.5952, val. acc. = 0.3259
# epoch 4: loss = 1.5714, val. acc. = 0.3093
# epoch 5: loss = 1.5437, val. acc. = 0.3480
# epoch 6: loss = 1.5038, val. acc. = 0.3972
# epoch 7: loss = 1.4699, val. acc. = 0.4323
# epoch 8: loss = 1.4185, val. acc. = 0.4966
# epoch 9: loss = 1.3505, val. acc. = 0.5786
# epoch 10: loss = 1.2511, val. acc. = 0.6409
# epoch 11: loss = 1.1417, val. acc. = 0.6809
# epoch 12: loss = 1.0226, val. acc. = 0.7064
# epoch 13: loss = 0.9002, val. acc. = 0.7082
# epoch 14: loss = 0.7959, val. acc. = 0.7361
# epoch 15: loss = 0.6995, val. acc. = 0.7563
# epoch 16: loss = 0.6209, val. acc. = 0.7647
# epoch 17: loss = 0.5818, val. acc. = 0.7808
# epoch 18: loss = 0.5281, val. acc. = 0.7825
# epoch 19: loss = 0.4896, val. acc. = 0.7858
# epoch 20: loss = 0.4599, val. acc. = 0.7868
# epoch 21: loss = 0.4370, val. acc. = 0.7912
# epoch 22: loss = 0.4159, val. acc. = 0.7997
# epoch 23: loss = 0.3902, val. acc. = 0.8028
# epoch 24: loss = 0.3719, val. acc. = 0.8052
# epoch 25: loss = 0.3508, val. acc. = 0.8098
# epoch 26: loss = 0.3280, val. acc. = 0.8139
# epoch 27: loss = 0.3123, val. acc. = 0.8186
# epoch 28: loss = 0.2968, val. acc. = 0.8197
# epoch 29: loss = 0.2826, val. acc. = 0.8158
# epoch 30: loss = 0.2659, val. acc. = 0.8366
# epoch 31: loss = 0.2470, val. acc. = 0.8470
# epoch 32: loss = 0.2352, val. acc. = 0.8529
# epoch 33: loss = 0.2124, val. acc. = 0.8642
# epoch 34: loss = 0.2092, val. acc. = 0.8611
# epoch 35: loss = 0.1933, val. acc. = 0.8733
# epoch 36: loss = 0.1970, val. acc. = 0.8829
# epoch 37: loss = 0.1751, val. acc. = 0.8739
# epoch 38: loss = 0.1738, val. acc. = 0.8754
# epoch 39: loss = 0.1673, val. acc. = 0.8744
# epoch 40: loss = 0.1557, val. acc. = 0.8720
# epoch 41: loss = 0.1421, val. acc. = 0.8763
# epoch 42: loss = 0.1504, val. acc. = 0.8858
# epoch 43: loss = 0.1467, val. acc. = 0.8796
# epoch 44: loss = 0.1264, val. acc. = 0.8881
# epoch 45: loss = 0.1250, val. acc. = 0.8834
# epoch 46: loss = 0.1147, val. acc. = 0.8894
# epoch 47: loss = 0.1297, val. acc. = 0.8960
# epoch 48: loss = 0.1196, val. acc. = 0.8921
# epoch 49: loss = 0.1120, val. acc. = 0.8917
# epoch 50: loss = 0.1028, val. acc. = 0.8988
# epoch 51: loss = 0.1103, val. acc. = 0.9046
# epoch 52: loss = 0.1024, val. acc. = 0.9035
# epoch 53: loss = 0.0860, val. acc. = 0.8975
# epoch 54: loss = 0.0845, val. acc. = 0.8994
# epoch 55: loss = 0.0866, val. acc. = 0.8961
# epoch 56: loss = 0.0793, val. acc. = 0.9004
# epoch 57: loss = 0.0693, val. acc. = 0.8952
# epoch 58: loss = 0.0784, val. acc. = 0.9005
# epoch 59: loss = 0.0747, val. acc. = 0.8918
# epoch 60: loss = 0.0625, val. acc. = 0.9012
# epoch 61: loss = 0.0701, val. acc. = 0.8979
# epoch 62: loss = 0.0733, val. acc. = 0.9013
# epoch 63: loss = 0.0606, val. acc. = 0.8977
# epoch 64: loss = 0.0609, val. acc. = 0.9080
# epoch 65: loss = 0.0647, val. acc. = 0.9009
# epoch 66: loss = 0.0614, val. acc. = 0.9029
# epoch 67: loss = 0.0406, val. acc. = 0.9027
# epoch 68: loss = 0.0453, val. acc. = 0.9057
# epoch 69: loss = 0.0517, val. acc. = 0.8996
# epoch 70: loss = 0.0429, val. acc. = 0.9046
# epoch 71: loss = 0.0561, val. acc. = 0.9054
# epoch 72: loss = 0.0514, val. acc. = 0.9091
# epoch 73: loss = 0.0422, val. acc. = 0.9051
# epoch 74: loss = 0.0393, val. acc. = 0.9064
# epoch 75: loss = 0.0413, val. acc. = 0.9046
# epoch 76: loss = 0.0364, val. acc. = 0.9079
# epoch 77: loss = 0.0360, val. acc. = 0.9026
# epoch 78: loss = 0.0277, val. acc. = 0.9099
# epoch 79: loss = 0.0405, val. acc. = 0.9035
# epoch 80: loss = 0.0325, val. acc. = 0.9038
# epoch 81: loss = 0.0284, val. acc. = 0.9045
# epoch 82: loss = 0.0308, val. acc. = 0.9105
# epoch 83: loss = 0.0341, val. acc. = 0.9095
# epoch 84: loss = 0.0266, val. acc. = 0.9142
# epoch 85: loss = 0.0343, val. acc. = 0.9149
# epoch 86: loss = 0.0333, val. acc. = 0.9099
# epoch 87: loss = 0.0303, val. acc. = 0.9036
# epoch 88: loss = 0.0312, val. acc. = 0.9031
# epoch 89: loss = 0.0281, val. acc. = 0.9070
# epoch 90: loss = 0.0286, val. acc. = 0.9089
# epoch 91: loss = 0.0314, val. acc. = 0.9200
# epoch 92: loss = 0.0234, val. acc. = 0.9136
# epoch 93: loss = 0.0211, val. acc. = 0.9133
# epoch 94: loss = 0.0239, val. acc. = 0.9068
# epoch 95: loss = 0.0347, val. acc. = 0.9086
# epoch 96: loss = 0.0284, val. acc. = 0.9165
# epoch 97: loss = 0.0279, val. acc. = 0.9254
# epoch 98: loss = 0.0309, val. acc. = 0.9113
# epoch 99: loss = 0.0200, val. acc. = 0.9110
# epoch 100: loss = 0.0475, val. acc. = 0.9092
# epoch 101: loss = 0.0211, val. acc. = 0.9058
# epoch 102: loss = 0.0314, val. acc. = 0.9163
# epoch 103: loss = 0.0315, val. acc. = 0.9211
# epoch 104: loss = 0.0190, val. acc. = 0.9125
# epoch 105: loss = 0.0246, val. acc. = 0.9162
# epoch 106: loss = 0.0208, val. acc. = 0.9111
# epoch 107: loss = 0.0196, val. acc. = 0.9220
# epoch 108: loss = 0.0214, val. acc. = 0.9117
# epoch 109: loss = 0.0201, val. acc. = 0.9131
# epoch 110: loss = 0.0235, val. acc. = 0.9249
# epoch 111: loss = 0.0245, val. acc. = 0.9192
# epoch 112: loss = 0.0154, val. acc. = 0.9171
# epoch 113: loss = 0.0171, val. acc. = 0.9153
# epoch 114: loss = 0.0215, val. acc. = 0.9206
# epoch 115: loss = 0.0199, val. acc. = 0.9159
# epoch 116: loss = 0.0208, val. acc. = 0.9200
# epoch 117: loss = 0.0172, val. acc. = 0.9127
# epoch 118: loss = 0.0164, val. acc. = 0.9201
# epoch 119: loss = 0.0155, val. acc. = 0.9259
# epoch 120: loss = 0.0192, val. acc. = 0.9259
# epoch 121: loss = 0.0159, val. acc. = 0.9211
# epoch 122: loss = 0.0143, val. acc. = 0.9275
# epoch 123: loss = 0.0146, val. acc. = 0.9168
# epoch 124: loss = 0.0145, val. acc. = 0.9220
# epoch 125: loss = 0.0159, val. acc. = 0.9211
# epoch 126: loss = 0.0151, val. acc. = 0.9274
# epoch 127: loss = 0.0124, val. acc. = 0.9212
# epoch 128: loss = 0.0141, val. acc. = 0.9364
# epoch 129: loss = 0.0132, val. acc. = 0.9168
# epoch 130: loss = 0.0155, val. acc. = 0.9272
# epoch 131: loss = 0.0158, val. acc. = 0.9223
# epoch 132: loss = 0.0141, val. acc. = 0.9255
# epoch 133: loss = 0.0148, val. acc. = 0.9255
# epoch 134: loss = 0.0129, val. acc. = 0.9217
# epoch 135: loss = 0.0165, val. acc. = 0.9287
# epoch 136: loss = 0.0137, val. acc. = 0.9153
# epoch 137: loss = 0.0126, val. acc. = 0.9320
# epoch 138: loss = 0.0116, val. acc. = 0.9311
# epoch 139: loss = 0.0120, val. acc. = 0.9296
# epoch 140: loss = 0.0121, val. acc. = 0.9284
# epoch 141: loss = 0.0117, val. acc. = 0.9267
# epoch 142: loss = 0.0119, val. acc. = 0.9271
# epoch 143: loss = 0.0111, val. acc. = 0.9248
# epoch 144: loss = 0.0118, val. acc. = 0.9224
# epoch 145: loss = 0.0075, val. acc. = 0.9314
# epoch 146: loss = 0.0073, val. acc. = 0.9312
# epoch 147: loss = 0.0148, val. acc. = 0.9223
# epoch 148: loss = 0.0104, val. acc. = 0.9278
# epoch 149: loss = 0.0111, val. acc. = 0.9295
# epoch 150: loss = 0.0156, val. acc. = 0.9224
# epoch 151: loss = 0.0108, val. acc. = 0.9283
# epoch 152: loss = 0.0110, val. acc. = 0.9160
# epoch 153: loss = 0.0117, val. acc. = 0.9252
# epoch 154: loss = 0.0116, val. acc. = 0.9348
# epoch 155: loss = 0.0089, val. acc. = 0.9162
# epoch 156: loss = 0.0080, val. acc. = 0.9264
# epoch 157: loss = 0.0114, val. acc. = 0.9228
# epoch 158: loss = 0.0096, val. acc. = 0.9335
# epoch 159: loss = 0.0099, val. acc. = 0.9328
# epoch 160: loss = 0.0081, val. acc. = 0.9202
# epoch 161: loss = 0.0141, val. acc. = 0.9319
# epoch 162: loss = 0.0087, val. acc. = 0.9296
# epoch 163: loss = 0.0091, val. acc. = 0.9347
# epoch 164: loss = 0.0103, val. acc. = 0.9179
# epoch 165: loss = 0.0112, val. acc. = 0.9265
# epoch 166: loss = 0.0135, val. acc. = 0.9355
# epoch 167: loss = 0.0066, val. acc. = 0.9261
# epoch 168: loss = 0.0082, val. acc. = 0.9298
# epoch 169: loss = 0.0064, val. acc. = 0.9330
# epoch 170: loss = 0.0098, val. acc. = 0.9360
# epoch 171: loss = 0.0079, val. acc. = 0.9285
# epoch 172: loss = 0.0074, val. acc. = 0.9203
# epoch 173: loss = 0.0064, val. acc. = 0.9263
# epoch 174: loss = 0.0134, val. acc. = 0.9322
# epoch 175: loss = 0.0077, val. acc. = 0.9297
# epoch 176: loss = 0.0078, val. acc. = 0.9357
# epoch 177: loss = 0.0058, val. acc. = 0.9264
# epoch 178: loss = 0.0081, val. acc. = 0.9255
# epoch 179: loss = 0.0067, val. acc. = 0.9342
# epoch 180: loss = 0.0079, val. acc. = 0.9277
# epoch 181: loss = 0.0061, val. acc. = 0.9414
# epoch 182: loss = 0.0052, val. acc. = 0.9401
# epoch 183: loss = 0.0078, val. acc. = 0.9355
# epoch 184: loss = 0.0066, val. acc. = 0.9294
# epoch 185: loss = 0.0050, val. acc. = 0.9315
# epoch 186: loss = 0.0070, val. acc. = 0.9390
# epoch 187: loss = 0.0058, val. acc. = 0.9314
# epoch 188: loss = 0.0047, val. acc. = 0.9396
# epoch 189: loss = 0.0060, val. acc. = 0.9389
# epoch 190: loss = 0.0100, val. acc. = 0.9338
# epoch 191: loss = 0.0064, val. acc. = 0.9302
# epoch 192: loss = 0.0047, val. acc. = 0.9318
# epoch 193: loss = 0.0055, val. acc. = 0.9301
# epoch 194: loss = 0.0063, val. acc. = 0.9362
# epoch 195: loss = 0.0050, val. acc. = 0.9397
# epoch 196: loss = 0.0082, val. acc. = 0.9362
# epoch 197: loss = 0.0057, val. acc. = 0.9344
# epoch 198: loss = 0.0041, val. acc. = 0.9422
# epoch 199: loss = 0.0074, val. acc. = 0.9434
# epoch 200: loss = 0.0050, val. acc. = 0.9377

# %%
print(y.value_counts(normalize=True))
# Out:
# Evaluate
# 1    0.284459
# 0    0.266693
# 4    0.237602
# 2    0.133151
# 3    0.078094
# Name: proportion, dtype: float64
